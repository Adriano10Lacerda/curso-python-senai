# %%
# Criar e manipular arquivos em excel
import xlsxwriter as xlsx
# Para gerenciar arquivos no sitema operacional
import os 

#-------------------------Gerar um caminho e um arquivo 

caminho = 'C:\\Users\\FIC\\Documents\\Adriano-Python\\'
arquivo = 'Exemplo-1.xlsx'

#-------------------------Criar um caminho em Excel

workbook = xlsx.Workbook(caminho + arquivo)
sheet = workbook.add_worksheet()
#-------------------------Escrever nas células
sheet.write('A1','Nome')
sheet.write('A2', 'Eduardo')
sheet.write('A3', 'Julia')
sheet.write('A4', 'José')
sheet.write('A5', 'Jauqeline')
#-------------------------Fechar o arquivo e salvar

workbook.close()

#-------------------------Abrir o documento

os.startfile(caminho + arquivo)

# %%
import  xlsxwriter as xlsx
import os
caminho = 'C:\\Users\\FIC\\Documents\\Adriano-Python\\'
arquivo = 'Exercicio-7.xlsx'

workbook = xlsx.Workbook(caminho + arquivo)
sheet = workbook.add_worksheet()
sheet.write('A1', ('Controle Fisico de Vendas'))
sheet.write('A2', 'Produto')
sheet.write('A3', 'Sapato')
sheet.write('A4', 'Calça')
sheet.write('A5', 'Camisa')
sheet.write('A6', 'Mochila')

sheet.write('B2', 'Jan')
sheet.write('B3', '14')
sheet.write('B4', '5')
sheet.write('B5', '4')
sheet.write('B6', '9')

sheet.write('C2', 'Fev')
sheet.write('C3', '2')
sheet.write('C4', '5')
sheet.write('C5', '5')
sheet.write('C6', '21')

sheet.write('D2', 'Mar')
sheet.write('D3', '7')
sheet.write('D4', '3')
sheet.write('D5', '12')
sheet.write('D6', '5')

sheet.write('E2', 'Minigrafico')

sheet.write('F2', 'Quantidade Vendida')

sheet.write('G2', 'Preço Unitario')
sheet.write('G3', 'R$ 55,00')
sheet.write('G4', 'R$ 36,00')
sheet.write('G5', 'R$ 18,00')
sheet.write('G6', 'R$ 32,00')

sheet.write('H2', 'Total de Vendas')

workbook.close()

os.startfile(caminho + arquivo)

# %% [markdown]
# ### Exemplo 02 - Aplicando formatação

# %%
import xlsxwriter as xlsx
import os
#-----------------------------Caminho do arquivo
caminho = 'C:\\Users\\FIC\\Documents\\Adriano-Python\\'
arquivo = 'Exemplo-2.xlsx'
#-----------------------------Criar um arquivo e uma aba
workbook = xlsx.Workbook(caminho + arquivo)
sheetDados = workbook.add_worksheet('Dados')
#-----------------------------Modificando a cor de fundo das celulas
corFonte = workbook.add_format()
corFonte.set_font_color('blue')

# Cor de fundo
corFundo = workbook.add_format({
                                'fg_color':'yellow',
                                'font_color':'green',
                                'bold':True,
                                'italic':True})

#-----------------------------Escrever nas celulas
sheetDados.write('A1','Nome', corFundo)
sheetDados.write('A2', 'Eduardo', corFonte)
sheetDados.write('A3', 'Julia', corFundo)
sheetDados.write('A4', 'José', corFonte)
sheetDados.write('A5', 'Jauqeline', corFundo)

sheetDados.write('B1', 'Idade', corFundo)
sheetDados.write('B2', 12, corFonte)
sheetDados.write('B3', 32, corFundo)
sheetDados.write('B4', 55, corFonte)
sheetDados.write('B5', 60, corFundo)
#----------------------------Fechar o documento e salvar
workbook.close()
#----------------------------Abrir o documento
os.startfile(caminho + arquivo)

# %%
import xlsxwriter as xlsx
import os

caminho = 'C:\\Users\\FIC\\Documents\\Adriano-Python\\'
arquivo = 'Exercicio-6.xlsx'

workbook = xlsx.Workbook(caminho + arquivo)
sheetDados = workbook.add_worksheet('Dados')

# Formatação do titulo
corTitulo = workbook.add_format({
                                'bold':True,
                                'font_size':18,
                                'align': 'center'
                                })


# Formatação Celulas A
corCabecalholinhas = workbook.add_format({
                                'fg_color':'yellow',# Cor preenchimento
                                'font_color':'green',# Cor da fonte
                                'bold':True, # Negrito
                                'italic':True, # Italico
                                'border':True # Aplicar bordas
                                })
# Formatação valores
corValores = workbook.add_format({
                                'num_format': 'R$ #,##0'
                                })
# Formatação dos totais
corTotais = workbook.add_format({
                                'num_format': 'R$ #,##0',
                                'fg_color': '#F4D0C4',
                                'font_color': '#1D3857',
                                'bold': True
                                })


sheetDados.merge_range('A1:C1', 'Controle de Custo', corTitulo)
sheetDados.merge_range('A2:A3', 'Itens', corValores)

sheetDados.write('A4', 'Salário')
sheetDados.write('A5', 'Horas Extras')
sheetDados.write('A6', 'Previdência Social')
sheetDados.write('A7', 'FGTS')
sheetDados.write('A8', 'Aluguel')
sheetDados.write('A9', 'Luz/Água/Telefone')
sheetDados.write('A10', 'Mat. Expediente')
sheetDados.write('A11', 'Outras Despesas')
sheetDados.write('A12', 'Total', corTotais)

sheetDados.write('B2', 'Total 1°Trimestre', corValores)
sheetDados.write('B3', 'Previsão', corValores)
sheetDados.write('B4', 'R$ 2.000,00')
sheetDados.write('B5', 'R$ 3.150,00')
sheetDados.write('B6', 'R$ 4.300,00')
sheetDados.write('B7', 'R$ 5.450,00')
sheetDados.write('B8', 'R$ 6.600,00')
sheetDados.write('B9', 'R$ 7.750,00')
sheetDados.write('B10', 'R$ 8.900,00')
sheetDados.write('B11', 'R$ 10.050,00')

sheetDados.write('C3', 'Gastos', corValores)
sheetDados.write('C4', 1550)
sheetDados.write('C5', 2550)
sheetDados.write('C6', 3550)
sheetDados.write('C7', 4550)
sheetDados.write('C8', 5550)
sheetDados.write('C9', 6550)
sheetDados.write('C10', 7550)
sheetDados.write('C11', 8550)
# Out:
# 0
